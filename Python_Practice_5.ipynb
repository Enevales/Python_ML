# %% [markdown]
# <a href="https://colab.research.google.com/github/Enevales/Python_ML/blob/main/Python_Practice_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot

def parser(x):
    return datetime.strptime('198'+x,'%Y-%m') #преобразуем строку в datetime
series = pd.read_csv('sample_data/shampoo_sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# выводим первые пять строк
print(series.head())
# строим график
series.plot()
pyplot.show()

# анализ данных
series.describe()

#строим скользящую среднюю
series.rolling(window = 2, center = False).mean().plot(style = 'r--')
plt.show()

#------------------------------------------------------------------------
# Out:
# Month
# 1981-01-01    266.0
# 1981-02-01    145.9
# 1981-03-01    183.1
# 1981-04-01    119.3
# 1981-05-01    180.3
# Name: Sales, dtype: float64
